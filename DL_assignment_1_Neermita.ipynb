# %% [markdown]
# <a href="https://colab.research.google.com/github/Neermita18/Deep-Learning/blob/main/DL_assignment_1_Neermita.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
from torchvision import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda

# %%
pip install kagglehub

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("fedesoriano/stellar-classification-dataset-sdss17")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 6.89M/6.89M [00:00<00:00, 26.4MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/fedesoriano/stellar-classification-dataset-sdss17/versions/1

# %%
df= pd.read_csv("/root/.cache/kagglehub/datasets/fedesoriano/stellar-classification-dataset-sdss17/versions/1/star_classification.csv")

# %%
df
# Out:
#              obj_ID       alpha      delta         u         g         r  \
# 0      1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1      1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2      1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3      1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4      1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
# ...             ...         ...        ...       ...       ...       ...
# 99995  1.237679e+18   39.620709  -2.594074  22.16759  22.97586  21.90404
# 99996  1.237679e+18   29.493819  19.798874  22.69118  22.38628  20.45003
# 99997  1.237668e+18  224.587407  15.700707  21.16916  19.26997  18.20428
# 99998  1.237661e+18  212.268621  46.660365  25.35039  21.63757  19.91386
# 99999  1.237661e+18  196.896053  49.464643  22.62171  21.79745  20.60115
#
#               i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# ...

# %%
df["class"]
# Out:
# 0        GALAXY
# 1        GALAXY
# 2        GALAXY
# 3        GALAXY
# 4        GALAXY
#           ...
# 99995    GALAXY
# 99996    GALAXY
# 99997    GALAXY
# 99998    GALAXY
# 99999    GALAXY
# Name: class, Length: 100000, dtype: object

# %%
class AstroDataset(Dataset):
  def __init__(self, df, X_transform=None, y_transform=None):
    self.data = df
    self.X_transform = X_transform
    self.y_transform= y_transform
  def __len__(self):
    return self.data.shape[0]
  def __getitem__(self, idx):
    X= self.data.drop(columns=["class"])
    y= self.data["class"]
    X = X.iloc[idx]
    y = y.iloc[idx]
    if self.X_transform:
      X= self.X_transform(X)
    if self.y_transform:
      y= self.y_transform(y)
    return X,y

# %%
train_dataset= AstroDataset(df)

# %%
a,b=train_dataset[0]

# %%
a
# Out:
# obj_ID         1.237661e+18
# alpha          1.356891e+02
# delta          3.249463e+01
# u              2.387882e+01
# g              2.227530e+01
# r              2.039501e+01
# i              1.916573e+01
# z              1.879371e+01
# run_ID         3.606000e+03
# rerun_ID       3.010000e+02
# cam_col        2.000000e+00
# field_ID       7.900000e+01
# spec_obj_ID    6.543777e+18
# redshift       6.347936e-01
# plate          5.812000e+03
# MJD            5.635400e+04
# fiber_ID       1.710000e+02
# Name: 0, dtype: float64

# %%
b
# Out:
# 'GALAXY'
